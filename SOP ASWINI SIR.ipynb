# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r'D:\DOP Aswini Sir\NCDEX_FUTUREEOD.csv')
df.head(10)
# Out:
# D:\random shiz\Program Files (x86)\New folder\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   FutureDate Instrument     Symbol Expiry_Date  Strike_Price  Option_Type  \
# 0    16:16.8     FUTCOM  BARLEYJPR     00:00.0             0          NaN
# 1    37:43.9     FUTCOM  COTTONGUJ     00:00.0             0          NaN
# 2    24:26.6     FUTCOM  RBRRS4KOC     00:00.0             0          NaN
# 3    11:24.1     FUTCOM  GARGUMJDR     00:00.0             0          NaN
# 4    28:19.6     FUTCOM  KAPASSRNR     00:00.0             0          NaN
# 5    00:13.9     FUTCOM  GARGUMJDR     00:00.0             0          NaN
# 6    53:27.0     FUTCOM  KAPASSRNR     00:00.0             0          NaN
# 7    58:13.5     FUTCOM  SUGARM200     00:00.0             0          NaN
# ...

# %%
df2 = pd.read_csv(r'D:\DOP Aswini Sir\MCX_FUTUREEOD.csv')
df2.head(10)
# Out:
#                       DATE COMSYMBOL                  EXPDATE     OPEN  \
# 0  2018-03-16 00:00:00.000    SILVER  2019-03-05 00:00:00.000      0.0
# 1  2018-03-16 00:00:00.000   SILVERM  2019-02-28 00:00:00.000      0.0
# 2  2018-03-19 00:00:00.000    SILVER  2019-03-05 00:00:00.000      0.0
# 3  2018-03-19 00:00:00.000   SILVERM  2019-02-28 00:00:00.000      0.0
# 4  2018-03-20 00:00:00.000    SILVER  2019-03-05 00:00:00.000  40750.0
# 5  2018-03-20 00:00:00.000   SILVERM  2019-02-28 00:00:00.000      0.0
# 6  2018-03-21 00:00:00.000    SILVER  2019-03-05 00:00:00.000      0.0
# 7  2018-03-21 00:00:00.000   SILVERM  2019-02-28 00:00:00.000      0.0
# 8  2018-03-22 00:00:00.000    SILVER  2019-03-05 00:00:00.000      0.0
# 9  2018-03-22 00:00:00.000   SILVERM  2019-02-28 00:00:00.000      0.0
#
#       HIGH      LOW    CLOSE  VOLUME   VALUE  OI                PREV_DATE  \
# 0      0.0      0.0  40881.0       0     0.0   0                      NaN
# ...

# %%
df3 = pd.read_csv(r'D:\DOP Aswini Sir\NCDEX_SPOTEOD.csv')
df3.head(10)
# Out:
#      SpotDate      Time      Symbol     Price Flag
# 0  16-02-2009  00:05:00  CHLL334GTR   5271.00    A
# 1  16-02-2009  00:08:00   COTI31GTR  21726.50    A
# 2  16-02-2009  00:16:00   RBDPLNKAK    341.55    A
# 3  16-02-2009  00:25:00   MAIZYRKRM    806.55    A
# 4  16-02-2009  00:30:00   MAIZYRDNG    813.85    A
# 5  16-02-2009  00:42:00   CRDPOLKAK    300.05    A
# 6  16-02-2009  00:42:00   SUGARMBLG   2106.20    A
# 7  16-02-2009  00:42:00   SUGARSBLG   2064.60    A
# 8  16-02-2009  00:43:00   GURCHMUZR    748.00    A
# 9  16-02-2009  00:45:00  CSHW320KLM   5879.30    A

# %%
df4 = pd.read_csv(r'D:\DOP Aswini Sir\MCX_SPOTEOD.csv')
df4.head(10)
# Out:
#   COMSYMBOL      UNIT MARKET   PRICE                  UPDTIME Flag
# 0    ALMOND     1 KGS  DELHI  315.25  2009-05-12 19:55:38.000    A
# 1    ALMOND  1 KGS     DELHI  316.25  2009-05-13 20:01:11.000    A
# 2    ALMOND  1 KGS     DELHI  309.00  2009-05-14 19:57:56.000    A
# 3    ALMOND  1 KGS     DELHI  307.00  2009-05-15 20:16:47.000    A
# 4    ALMOND  1 KGS     DELHI  307.00  2009-05-16 14:02:56.000    A
# 5    ALMOND  1 KGS     DELHI  303.75  2009-05-18 19:46:40.000    A
# 6    ALMOND  1 KGS     DELHI  301.25  2009-05-19 23:03:33.000    A
# 7    ALMOND  1 KGS     DELHI  299.50  2009-05-20 18:44:19.000    A
# 8    ALMOND  1 KGS     DELHI  298.00  2009-05-21 19:54:55.000    A
# 9    ALMOND  1 KGS     DELHI  297.25  2009-05-22 20:28:46.000    A

# %%
df.shape
# Out:
# (248595, 18)

# %%
df2.shape
# Out:
# (8642, 17)

# %%
df3.shape
# Out:
# (316622, 5)

# %%
df4.shape
# Out:
# (131121, 6)

# %%
df4['UPDTIME'] = pd.to_datetime(df4['UPDTIME'],infer_datetime_format=True)
df4_idx = df4.set_index(["UPDTIME"], drop=True)
df4_idx.head(5)
# Out:
#                     COMSYMBOL      UNIT MARKET   PRICE Flag
# UPDTIME
# 2009-05-12 19:55:38    ALMOND     1 KGS  DELHI  315.25    A
# 2009-05-13 20:01:11    ALMOND  1 KGS     DELHI  316.25    A
# 2009-05-14 19:57:56    ALMOND  1 KGS     DELHI  309.00    A
# 2009-05-15 20:16:47    ALMOND  1 KGS     DELHI  307.00    A
# 2009-05-16 14:02:56    ALMOND  1 KGS     DELHI  307.00    A

# %%
df3['DateTime']=pd.to_datetime(df3['SpotDate'] + ' ' + df3['Time'])
#df3
df3_idx = df3.set_index(['DateTime'])
df3_idx.head(5)
# Out:
#                        SpotDate      Time      Symbol     Price Flag
# DateTime
# 2009-02-16 00:05:00  16-02-2009  00:05:00  CHLL334GTR   5271.00    A
# 2009-02-16 00:08:00  16-02-2009  00:08:00   COTI31GTR  21726.50    A
# 2009-02-16 00:16:00  16-02-2009  00:16:00   RBDPLNKAK    341.55    A
# 2009-02-16 00:25:00  16-02-2009  00:25:00   MAIZYRKRM    806.55    A
# 2009-02-16 00:30:00  16-02-2009  00:30:00   MAIZYRDNG    813.85    A

# %%
df2['DATE'] = pd.to_datetime(df2['DATE'],infer_datetime_format=True)
df2['EXPDATE'] = pd.to_datetime(df2['EXPDATE'],infer_datetime_format=True)
df2['PREV_DATE'] = pd.to_datetime(df2['PREV_DATE'],infer_datetime_format=True)
df2_idx = df2.set_index(["DATE"], drop=True)
df2_idx.head(5)
# Out:
#            COMSYMBOL    EXPDATE     OPEN     HIGH      LOW    CLOSE  VOLUME  \
# DATE
# 2018-03-16    SILVER 2019-03-05      0.0      0.0      0.0  40881.0       0
# 2018-03-16   SILVERM 2019-02-28      0.0      0.0      0.0  40892.0       0
# 2018-03-19    SILVER 2019-03-05      0.0      0.0      0.0  40925.0       0
# 2018-03-19   SILVERM 2019-02-28      0.0      0.0      0.0  41078.0       0
# 2018-03-20    SILVER 2019-03-05  40750.0  40750.0  40750.0  40750.0       1
#
#              VALUE  OI  PREV_DATE  PREV_PRICE  CHANGE  PERCHANGE  PREVOI  \
# DATE
# 2018-03-16     0.0   0        NaT     40881.0     0.0   0.000000     NaN
# 2018-03-16     0.0   0        NaT     40892.0     0.0   0.000000     NaN
# 2018-03-19     0.0   0 2018-03-16     40881.0    44.0   0.107629     0.0
# 2018-03-19     0.0   0 2018-03-16     40892.0   186.0   0.454857     0.0
# 2018-03-20  1222.5   1 2018-03-19     40925.0  -175.0  -0.427611     0.0
#
#             CHANGE_OI Flag
# DATE
# ...

# %%
df2_idx.nunique()
# Out:
# COMSYMBOL       29
# EXPDATE         38
# OPEN          2526
# HIGH          2517
# LOW           2531
# CLOSE         5291
# VOLUME        1549
# VALUE         3217
# OI            1744
# PREV_DATE      229
# PREV_PRICE    5298
# CHANGE        2006
# PERCHANGE     6831
# PREVOI        1703
# CHANGE_OI        0
# Flag             2
# dtype: int64

# %%
df3_idx.nunique()
# Out:
# Symbol      299
# Price     81257
# Flag          1
# dtype: int64

# %%
df4_idx.nunique()
# Out:
# COMSYMBOL      110
# UNIT            55
# MARKET          54
# PRICE        37188
# Flag             1
# dtype: int64

# %%
df.nunique()
# Out:
# FutureDate      36886
# Instrument          1
# Symbol            112
# Expiry_Date        61
# Strike_Price        1
# Option_Type         0
# Market_Type         1
# LTP             37749
# TTQ             21511
# Open_Price      29771
# High_Price      30798
# Low_Price       30344
# OI               1134
# Prev_Price      37558
# Price_Change    13498
# Prev_OI          1293
# OI_Change         970
# Flag                1
# dtype: int64

# %%
df4_idx = df4_idx.sort_index(axis=1, ascending=True)
df4_idx = df4_idx.iloc[::-1]

# %%
df3_idx = df3_idx.sort_index(axis=1,ascending=True)
df3_idx=df3_idx.iloc[::-1]

# %%
df2_idx = df2_idx.sort_index(axis=1,ascending=True)
df2_idx=df2_idx.iloc[::-1]

# %%
#df4_idx2 = df4_idx[df4_idx['COMSYMBOL']== 'ALMOND']
data = df4_idx[['PRICE']]
#df4_idx.plot(y='PRICE',figsize=(24,18))
df4_idx.sort_index(axis=0, ascending=True,inplace=True)

#df4_idx3 = df4_idx[df4_idx['COMSYMBOL']== 'ALUMINIUM']
#data2 = df4_idx3[['PRICE']]
#data2.plot(y='PRICE',figsize=(24,18))
#data2.sort_index(axis=0, ascending=True,inplace=True)
#plt.show()

# %%
#df4_idx

# %%
df4_idx.nunique()
# Out:
# COMSYMBOL      110
# Flag             1
# MARKET          54
# PRICE        37188
# UNIT            55
# dtype: int64

# %%
df4_idx.dtypes
# Out:
# COMSYMBOL     object
# Flag          object
# MARKET        object
# PRICE        float64
# UNIT          object
# dtype: object

# %%
 df4_idx['COMSYMBOL'] = df4_idx['COMSYMBOL'].astype('category')

# %%
df4_idx.dtypes
# Out:
# COMSYMBOL    category
# Flag           object
# MARKET         object
# PRICE         float64
# UNIT           object
# dtype: object

# %%
df4_idx.sort_values(inplace=True,by=['COMSYMBOL','UPDTIME'])
#df4_idx.head(1000)

# %%
df4_idx.drop(['Flag','MARKET','UNIT'],axis=1)
# Out:
#                     COMSYMBOL   PRICE
# UPDTIME
# 2009-05-12 19:55:38    ALMOND  315.25
# 2009-05-13 20:01:11    ALMOND  316.25
# 2009-05-14 19:57:56    ALMOND  309.00
# 2009-05-15 20:16:47    ALMOND  307.00
# 2009-05-16 14:02:56    ALMOND  307.00
# 2009-05-18 19:46:40    ALMOND  303.75
# 2009-05-19 23:03:33    ALMOND  301.25
# 2009-05-20 18:44:19    ALMOND  299.50
# 2009-05-21 19:54:55    ALMOND  298.00
# 2009-05-22 20:28:46    ALMOND  297.25
# 2009-05-23 14:00:10    ALMOND  297.00
# 2009-05-25 16:53:54    ALMOND  296.50
# 2009-05-26 18:00:08    ALMOND  297.00
# 2009-05-27 19:48:55    ALMOND  298.00
# 2009-05-28 20:23:47    ALMOND  299.50
# 2009-05-29 20:10:16    ALMOND  300.75
# 2009-05-30 14:01:39    ALMOND  301.25
# 2009-06-01 00:00:00    ALMOND  299.25
# 2009-06-02 00:00:00    ALMOND  298.75
# 2009-06-03 00:00:00    ALMOND  298.00
# 2009-06-04 00:00:00    ALMOND  294.50
# 2009-06-05 20:31:00    ALMOND  294.00
# 2009-06-06 14:06:00    ALMOND  295.00
# ...

# %%
data = df4_idx[df4_idx['COMSYMBOL']=="ALMOND"]
data.plot(y='PRICE',figsize=(24,18),label='almond')

# %%
data.index.values
# Out:
# array(['2009-05-12T19:55:38.000000000', '2009-05-13T20:01:11.000000000',
#        '2009-05-14T19:57:56.000000000', ...,
#        '2019-02-11T16:16:00.000000000', '2019-02-12T16:22:00.000000000',
#        '2019-02-13T16:34:00.000000000'], dtype='datetime64[ns]')

# %%
diff = data.index.values[-1] - data.index.values[0]
days = diff.astype('timedelta64[D]')

days = days / np.timedelta64(1, 'D')
years = int(days/365)
print("Total data: %d years"%years)
print("80 percent data = 2010 to %d"%(2009 + int(0.8*years)))
# Out:
# Total data: 9 years
# 80 percent data = 2010 to 2016

# %%
split_date = pd.Timestamp('01-01-2017')

train = data.loc[:split_date]
test = data.loc[split_date:]

ax = train.plot(figsize=(24,18))
test.plot(ax=ax)
plt.legend(['train', 'test'])
plt.show()
train.head(1)
# Out:
#                     COMSYMBOL Flag MARKET   PRICE   UNIT
# UPDTIME
# 2009-05-12 19:55:38    ALMOND    A  DELHI  315.25  1 KGS

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
#train.drop(["Flag","MARKET","COMSYMBOL","UNIT"],axis=1)
train2=train.drop(["Flag","MARKET","COMSYMBOL","UNIT"],axis=1)
test2=test.drop(["Flag","MARKET","COMSYMBOL","UNIT"],axis=1)
train_sc = sc.fit_transform(train2)
test_sc = sc.transform(test2)

# %%
X_train = train_sc[:-1]
y_train = train_sc[1:]

X_test = test_sc[:-1]
y_test = test_sc[1:]

# %%
from sklearn.metrics import r2_score

def adj_r2_score(r2, n, k):
    return 1-((1-r2)*((n-1)/(n-k-1)))


from sklearn.svm import SVR
regressor = SVR(kernel='rbf')

regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
y_pred = y_pred.reshape(-1,1)
y_test_tfm = sc.inverse_transform(y_test)
y_pred_tfm = sc.inverse_transform(y_pred)
plt.plot(y_test_tfm)
plt.plot(y_pred_tfm)

print('R-Squared: %f'%(r2_score(y_test_tfm, y_pred_tfm)))
# Out:
# R-Squared: 0.902937
# D:\random shiz\Program Files (x86)\New folder\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# D:\random shiz\Program Files (x86)\New folder\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
from keras.models import Sequential
from keras.layers import Dense
import keras.backend as K
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam
from keras.models import load_model

# %%
K.clear_session()

model = Sequential()
model.add(Dense(12, input_dim=1, activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
early_stop = EarlyStopping(monitor='loss', patience=2, verbose=1)
history = model.fit(X_train, y_train, epochs=200, batch_size=1, verbose=1, callbacks=[early_stop], shuffle=False)
# Out:
# Epoch 1/200
# 2035/2035 [==============================] - 2s 867us/step - loss: 2.4861e-04
# Epoch 2/200
# 2035/2035 [==============================] - 2s 852us/step - loss: 3.1453e-04
# Epoch 3/200
# 2035/2035 [==============================] - 2s 859us/step - loss: 1.9694e-04
# Epoch 4/200
# 2035/2035 [==============================] - 2s 774us/step - loss: 1.6892e-04
# Epoch 5/200
# 2035/2035 [==============================] - 2s 855us/step - loss: 1.6064e-04
# Epoch 6/200
# 2035/2035 [==============================] - 1s 593us/step - loss: 1.5610e-04
# Epoch 7/200
# 2035/2035 [==============================] - 1s 570us/step - loss: 1.5286e-04
# Epoch 8/200
# 2035/2035 [==============================] - 1s 572us/step - loss: 1.5132e-04
# Epoch 9/200
# 2035/2035 [==============================] - 1s 578us/step - loss: 1.5169e-04
# Epoch 10/200
# 2035/2035 [==============================] - 1s 574us/step - loss: 1.5250e-04
# Epoch 00010: early stopping

# %%
y_pred_test_ann = model.predict(X_test)
y_train_pred_ann = model.predict(X_train)
print("The R2 score on the Train set is:\t{:0.3f}".format(r2_score(y_train, y_train_pred_ann)))
r2_train = r2_score(y_train, y_train_pred_ann)
print("The Adjusted R2 score on the Train set is:\t{:0.3f}\n".format(adj_r2_score(r2_train, X_train.shape[0], X_train.shape[1])))
print("The R2 score on the Test set is:\t{:0.3f}".format(r2_score(y_test, y_pred_test_ann)))
r2_test = r2_score(y_test, y_pred_test_ann)
print("The Adjusted R2 score on the Test set is:\t{:0.3f}".format(adj_r2_score(r2_test, X_test.shape[0], X_test.shape[1])))
# Out:
# The R2 score on the Train set is:	0.944
# The Adjusted R2 score on the Train set is:	0.944
#
# The R2 score on the Test set is:	0.741
# The Adjusted R2 score on the Test set is:	0.740

# %%
model.save('ANN_NonShift.h5')

# %%
X_tr_t = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_tst_t = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
from keras.layers import LSTM
K.clear_session()
model_lstm = Sequential()
model_lstm.add(LSTM(7, input_shape=(1, X_train.shape[1]), activation='relu', kernel_initializer='lecun_uniform', return_sequences=False))
model_lstm.add(Dense(1))
model_lstm.compile(loss='mean_squared_error', optimizer='adam')
early_stop = EarlyStopping(monitor='loss', patience=5, verbose=1)
history_model_lstm = model_lstm.fit(X_tr_t, y_train, epochs=200, batch_size=10, verbose=1, shuffle=False, callbacks=[early_stop])
# Out:
# Epoch 1/200
# 2035/2035 [==============================] - 1s 433us/step - loss: 0.0205
# Epoch 2/200
# 2035/2035 [==============================] - 0s 143us/step - loss: 0.0197
# Epoch 3/200
# 2035/2035 [==============================] - 0s 132us/step - loss: 0.0104
# Epoch 4/200
# 2035/2035 [==============================] - 0s 138us/step - loss: 0.0046
# Epoch 5/200
# 2035/2035 [==============================] - 0s 140us/step - loss: 0.0018
# Epoch 6/200
# 2035/2035 [==============================] - 0s 135us/step - loss: 6.9179e-04
# Epoch 7/200
# 2035/2035 [==============================] - 0s 139us/step - loss: 3.2759e-04
# Epoch 8/200
# 2035/2035 [==============================] - 0s 138us/step - loss: 2.0520e-04
# Epoch 9/200
# 2035/2035 [==============================] - 0s 141us/step - loss: 1.6046e-04
# Epoch 10/200
# 2035/2035 [==============================] - 0s 132us/step - loss: 1.4160e-04
# Epoch 11/200
# ...

# %%
y_pred_test_lstm = model_lstm.predict(X_tst_t)
y_train_pred_lstm = model_lstm.predict(X_tr_t)
print("The R2 score on the Train set is:\t{:0.3f}".format(r2_score(y_train, y_train_pred_lstm)))
r2_train = r2_score(y_train, y_train_pred_lstm)
print("The Adjusted R2 score on the Train set is:\t{:0.3f}\n".format(adj_r2_score(r2_train, X_train.shape[0], X_train.shape[1])))
print("The R2 score on the Test set is:\t{:0.3f}".format(r2_score(y_test, y_pred_test_lstm)))
r2_test = r2_score(y_test, y_pred_test_lstm)
print("The Adjusted R2 score on the Test set is:\t{:0.3f}".format(adj_r2_score(r2_test, X_test.shape[0], X_test.shape[1])))
# Out:
# The R2 score on the Train set is:	0.998
# The Adjusted R2 score on the Train set is:	0.998
#
# The R2 score on the Test set is:	0.911
# The Adjusted R2 score on the Test set is:	0.911

# %%
model_lstm.save('LSTM_NonShift.h5')

# %%
model_ann = load_model('ANN_NonShift.h5')
model_lstm = load_model('LSTM_NonShift.h5')

# %%
score_ann= model_ann.evaluate(X_test, y_test, batch_size=1)
score_lstm= model_lstm.evaluate(X_tst_t, y_test, batch_size=1)
# Out:
# ...
# 508/508 [==============================] - 0s 755us/step

# %%
print('ANN: %f'%score_ann)
print('LSTM: %f'%score_lstm)
# Out:
# ANN: 0.000587
# LSTM: 0.000201

# %%
y_pred_test_ANN = model_ann.predict(X_test)
y_pred_test_LSTM = model_lstm.predict(X_tst_t)
y_train_pred_lstm = model_lstm.predict(X_tr_t)

# %%
col1 = pd.DataFrame(y_test, columns=['True'])
col2 = pd.DataFrame(y_pred_test_ANN, columns=['ANN_prediction'])
col3 = pd.DataFrame(y_pred_test_LSTM, columns=['LSTM_prediction'])
col4 = pd.DataFrame(history.history['loss'], columns=['Loss_ANN'])
col5 = pd.DataFrame(history_model_lstm.history['loss'], columns=['Loss_LSTM'])
results = pd.concat([col1, col2, col3, col4, col5], axis=1)
results.to_excel('PredictionResults_ANN-LSTM_NonShift.xlsx')

# %%
plt.plot(y_test, label='True')
plt.plot(y_pred_test_ANN, label='ANN')
plt.title("ANN's_Prediction")
plt.xlabel('Observation')
plt.ylabel('Price_Scaled')
plt.legend()
plt.show()

# %%
plt.plot(y_test, label='True')
plt.plot(y_pred_test_LSTM, label='LSTM')
plt.title("LSTM's_Prediction Forecast")
plt.xlabel('Observation')
plt.ylabel("Price_Scaled")
plt.legend()
plt.show()

# %%
plt.plot(y_train, label='True')
plt.plot(y_train_pred_lstm, label='LSTM')
plt.title("LSTM's_Prediction on Training")
plt.xlabel('Observation')
plt.ylabel('Price_Scaled')
plt.legend()
plt.show()

# %%
df3_idx['Symbol'] = df3_idx['Symbol'].astype('category')
#df3_idx

# %%
df3_idx.dtypes
# Out:
# SpotDate      object
# Time          object
# Symbol      category
# Price        float64
# Flag          object
# dtype: object

# %%
df3_idx.sort_values(inplace=True,by=['Symbol','Price'])
df3_idx.head(10)
# Out:
#                        SpotDate      Time     Symbol  Price Flag
# DateTime
# 2009-02-24 00:25:00  24-02-2009  00:25:00  ALUMINIUM  62.55    A
# 2009-02-20 00:20:00  20-02-2009  00:20:00  ALUMINIUM  63.05    A
# 2009-02-21 00:50:00  21-02-2009  00:50:00  ALUMINIUM  63.05    A
# 2009-02-18 00:20:00  18-02-2009  00:20:00  ALUMINIUM  63.85    A
# 2009-02-16 00:25:00  16-02-2009  00:25:00  ALUMINIUM  64.10    A
# 2009-02-17 00:25:00  17-02-2009  00:25:00  ALUMINIUM  64.40    A
# 2009-02-25 00:25:00  25-02-2009  00:25:00  ALUMINIUM  64.45    A
# 2009-02-19 00:25:00  19-02-2009  00:25:00  ALUMINIUM  64.60    A
# 2009-05-28 00:45:00  28-05-2009  00:45:00  ALUMINIUM  65.20    A
# 2009-09-03 00:45:00  09-03-2009  00:45:00  ALUMINIUM  65.35    A

# %%
df3_idx.drop(['Flag','SpotDate','Time'],axis=1)
# Out:
#                         Symbol   Price
# DateTime
# 2009-02-24 00:25:00  ALUMINIUM   62.55
# 2009-02-20 00:20:00  ALUMINIUM   63.05
# 2009-02-21 00:50:00  ALUMINIUM   63.05
# 2009-02-18 00:20:00  ALUMINIUM   63.85
# 2009-02-16 00:25:00  ALUMINIUM   64.10
# 2009-02-17 00:25:00  ALUMINIUM   64.40
# 2009-02-25 00:25:00  ALUMINIUM   64.45
# 2009-02-19 00:25:00  ALUMINIUM   64.60
# 2009-05-28 00:45:00  ALUMINIUM   65.20
# 2009-09-03 00:45:00  ALUMINIUM   65.35
# 2009-02-27 00:30:00  ALUMINIUM   65.40
# 2009-05-29 00:55:00  ALUMINIUM   65.45
# 2009-02-03 00:40:00  ALUMINIUM   65.75
# 2009-02-26 00:25:00  ALUMINIUM   66.10
# 2009-03-03 00:30:00  ALUMINIUM   66.40
# 2009-10-03 00:25:00  ALUMINIUM   66.40
# 2009-05-22 00:45:00  ALUMINIUM   66.40
# 2009-05-23 00:25:00  ALUMINIUM   66.40
# 2009-05-27 00:05:00  ALUMINIUM   66.45
# 2009-06-03 00:25:00  ALUMINIUM   66.60
# 2009-07-03 00:40:00  ALUMINIUM   66.60
# 2009-05-26 00:45:00  ALUMINIUM   66.90
# 2009-01-06 00:00:00  ALUMINIUM   66.95
# ...

# %%
data2 = df3_idx[df3_idx['Symbol']=="GUARSEED10"]
data2.sort_values(inplace=True,by=['DateTime','SpotDate'])
data2.plot(y='Price',figsize=(24,18),label='GUARSEED')
# Out:
# D:\random shiz\Program Files (x86)\New folder\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data2.index.values
data2.head(100)
# Out:
#                        SpotDate      Time      Symbol    Price Flag
# DateTime
# 2013-01-10 00:11:00  01-10-2013  00:11:00  GUARSEED10  6066.65    A
# 2013-01-11 00:18:00  01-11-2013  00:18:00  GUARSEED10  5338.90    A
# 2013-02-11 00:17:00  02-11-2013  00:17:00  GUARSEED10  5479.15    A
# 2013-02-12 00:09:00  02-12-2013  00:09:00  GUARSEED10  4622.20    A
# 2013-03-10 00:14:00  03-10-2013  00:14:00  GUARSEED10  5623.55    A
# 2013-03-12 00:13:00  03-12-2013  00:13:00  GUARSEED10  4700.00    A
# 2013-04-10 00:12:00  04-10-2013  00:12:00  GUARSEED10  5854.55    A
# 2013-04-12 00:10:00  04-12-2013  00:10:00  GUARSEED10  4857.15    A
# 2013-05-09 00:11:00  05-09-2013  00:11:00  GUARSEED10  8281.80    A
# 2013-05-10 00:13:00  05-10-2013  00:13:00  GUARSEED10  5800.00    A
# 2013-05-11 00:20:00  05-11-2013  00:20:00  GUARSEED10  5425.00    A
# 2013-05-12 00:21:00  05-12-2013  00:21:00  GUARSEED10  4792.35    A
# 2013-06-09 00:09:00  06-09-2013  00:09:00  GUARSEED10  7845.45    A
# ...

# %%
diff2 = data2.index.values[-1] - data2.index.values[0]
days2 = diff2.astype('timedelta64[D]')

days2 = days2 / np.timedelta64(1, 'D')
years2 = int(days2/365)
print("Total data: %d years"%years2)
print("80 percent data = 2010 to %d"%(2009 + int(0.8*years2)))
data2.sort_values(inplace=True,by=['DateTime'])
data2
# Out:
# Total data: 6 years
# 80 percent data = 2010 to 2013
# D:\random shiz\Program Files (x86)\New folder\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                        SpotDate      Time      Symbol    Price Flag
# DateTime
# 2013-01-10 00:11:00  01-10-2013  00:11:00  GUARSEED10  6066.65    A
# 2013-01-11 00:18:00  01-11-2013  00:18:00  GUARSEED10  5338.90    A
# 2013-02-11 00:17:00  02-11-2013  00:17:00  GUARSEED10  5479.15    A
# 2013-02-12 00:09:00  02-12-2013  00:09:00  GUARSEED10  4622.20    A
# 2013-03-10 00:14:00  03-10-2013  00:14:00  GUARSEED10  5623.55    A
# 2013-03-12 00:13:00  03-12-2013  00:13:00  GUARSEED10  4700.00    A
# 2013-04-10 00:12:00  04-10-2013  00:12:00  GUARSEED10  5854.55    A
# ...

# %%
data2.drop(["Flag","Symbol","SpotDate","Time"],axis=1)

split_date = pd.Timestamp('01-01-2017')

train2 = data2.loc[:split_date]
test2 = data2.loc[split_date:]

ax = train2.plot(figsize=(24,18))
test2.plot(ax=ax)
plt.legend(['train', 'test'])
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
train3=train2.drop(["Flag","Symbol","SpotDate","Time"],axis=1)
test3=test2.drop(["Flag","Symbol","SpotDate","Time"],axis=1)
train_sc2 = sc.fit_transform(train3)
test_sc2 = sc.transform(test3)

# %%
X_train2 = train_sc2[:-1]
y_train2 = train_sc2[1:]

X_test2 = test_sc2[:-1]
y_test2 = test_sc2[1:]

# %%
from sklearn.metrics import r2_score

def adj_r2_score(r2, n, k):
    return 1-((1-r2)*((n-1)/(n-k-1)))


from sklearn.svm import SVR
regressor = SVR(kernel='rbf')

regressor.fit(X_train2, y_train2)
y_pred2 = regressor.predict(X_test2)
y_pred2 = y_pred2.reshape(-1,1)
y_test_tfm2 = sc.inverse_transform(y_test2)
y_pred_tfm2 = sc.inverse_transform(y_pred2)
plt.plot(y_test_tfm2)
plt.plot(y_pred_tfm2)

print('R-Squared: %f'%(r2_score(y_test_tfm2, y_pred_tfm2)))
# Out:
# R-Squared: 0.478222
# D:\random shiz\Program Files (x86)\New folder\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# D:\random shiz\Program Files (x86)\New folder\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
K.clear_session()

model = Sequential()
model.add(Dense(12, input_dim=1, activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
early_stop = EarlyStopping(monitor='loss', patience=2, verbose=1)
history = model.fit(X_train2, y_train2, epochs=200, batch_size=1, verbose=1, callbacks=[early_stop], shuffle=False)
# Out:
# Epoch 1/200
# 843/843 [==============================] - 1s 819us/step - loss: 0.0099
# Epoch 2/200
# 843/843 [==============================] - 1s 606us/step - loss: 0.0063
# Epoch 3/200
# 843/843 [==============================] - 0s 584us/step - loss: 0.0061
# Epoch 4/200
# 843/843 [==============================] - 1s 596us/step - loss: 0.0060
# Epoch 5/200
# 843/843 [==============================] - 1s 658us/step - loss: 0.0059
# Epoch 6/200
# 843/843 [==============================] - 1s 841us/step - loss: 0.0059
# Epoch 7/200
# 843/843 [==============================] - 1s 675us/step - loss: 0.0059
# Epoch 8/200
# 843/843 [==============================] - 1s 763us/step - loss: 0.0059
# Epoch 9/200
# 843/843 [==============================] - 1s 593us/step - loss: 0.0059
# Epoch 10/200
# 843/843 [==============================] - 1s 861us/step - loss: 0.0059
# Epoch 11/200
# 843/843 [==============================] - 1s 871us/step - loss: 0.0059
# Epoch 12/200
# ...

# %%
y_pred_test_ann2 = model.predict(X_test2)
y_train_pred_ann2 = model.predict(X_train2)
print("The R2 score on the Train set is:\t{:0.3f}".format(r2_score(y_train2, y_train_pred_ann2)))
r2_train2 = r2_score(y_train2, y_train_pred_ann2)
print("The Adjusted R2 score on the Train set is:\t{:0.3f}\n".format(adj_r2_score(r2_train2, X_train2.shape[0], X_train2.shape[1])))
print("The R2 score on the Test set is:\t{:0.3f}".format(r2_score(y_test2, y_pred_test_ann2)))
r2_test2 = r2_score(y_test2, y_pred_test_ann2)
print("The Adjusted R2 score on the Test set is:\t{:0.3f}".format(adj_r2_score(r2_test2, X_test2.shape[0], X_test2.shape[1])))
# Out:
# The R2 score on the Train set is:	0.546
# The Adjusted R2 score on the Train set is:	0.545
#
# The R2 score on the Test set is:	0.292
# The Adjusted R2 score on the Test set is:	0.291

# %%
model.save('ANN_NonShift2.h5')

# %%
X_tr_t2 = X_train2.reshape(X_train2.shape[0], 1, X_train2.shape[1])
X_tst_t2 = X_test2.reshape(X_test2.shape[0], 1, X_test2.shape[1])

# %%
from keras.layers import LSTM
K.clear_session()
model_lstm2 = Sequential()
model_lstm2.add(LSTM(7, input_shape=(1, X_train2.shape[1]), activation='relu', kernel_initializer='lecun_uniform', return_sequences=False))
model_lstm2.add(Dense(1))
model_lstm2.compile(loss='mean_squared_error', optimizer='adam')
early_stop = EarlyStopping(monitor='loss', patience=5, verbose=1)
history_model_lstm2 = model_lstm2.fit(X_tr_t2, y_train2, epochs=200, batch_size=10, verbose=1, shuffle=False, callbacks=[early_stop])
# Out:
# Epoch 1/200
# 843/843 [==============================] - 1s 820us/step - loss: 0.1087
# Epoch 2/200
# 843/843 [==============================] - 0s 163us/step - loss: 0.0749
# Epoch 3/200
# 843/843 [==============================] - 0s 173us/step - loss: 0.0538
# Epoch 4/200
# 843/843 [==============================] - 0s 167us/step - loss: 0.0421
# Epoch 5/200
# 843/843 [==============================] - 0s 174us/step - loss: 0.0360
# Epoch 6/200
# 843/843 [==============================] - 0s 163us/step - loss: 0.0328
# Epoch 7/200
# 843/843 [==============================] - 0s 161us/step - loss: 0.0310
# Epoch 8/200
# 843/843 [==============================] - 0s 169us/step - loss: 0.0299
# Epoch 9/200
# 843/843 [==============================] - 0s 157us/step - loss: 0.0291
# Epoch 10/200
# 843/843 [==============================] - 0s 160us/step - loss: 0.0286
# Epoch 11/200
# 843/843 [==============================] - 0s 161us/step - loss: 0.0281
# Epoch 12/200
# ...

# %%
y_pred_test_lstm2 = model_lstm2.predict(X_tst_t2)
y_train_pred_lstm2 = model_lstm2.predict(X_tr_t2)
print("The R2 score on the Train set is:\t{:0.3f}".format(r2_score(y_train2, y_train_pred_lstm2)))
r2_train2 = r2_score(y_train2, y_train_pred_lstm2)
print("The Adjusted R2 score on the Train set is:\t{:0.3f}\n".format(adj_r2_score(r2_train2, X_train2.shape[0], X_train2.shape[1])))
print("The R2 score on the Test set is:\t{:0.3f}".format(r2_score(y_test2, y_pred_test_lstm2)))
r2_test2 = r2_score(y_test2, y_pred_test_lstm2)
print("The Adjusted R2 score on the Test set is:\t{:0.3f}".format(adj_r2_score(r2_test2, X_test2.shape[0], X_test2.shape[1])))
# Out:
# The R2 score on the Train set is:	-0.009
# The Adjusted R2 score on the Train set is:	-0.010
#
# The R2 score on the Test set is:	-0.432
# The Adjusted R2 score on the Test set is:	-0.434

# %%
model_lstm2.save('LSTM_NonShift2.h5')

# %%
model_ann2 = load_model('ANN_NonShift2.h5')
model_lstm2 = load_model('LSTM_NonShift.h5')

# %%
score_ann2= model_ann2.evaluate(X_test2, y_test2, batch_size=1)
score_lstm2= model_lstm2.evaluate(X_tst_t2, y_test2, batch_size=1)
# Out:
# ...
# 518/518 [==============================] - 0s 850us/step

# %%
print('ANN: %f'%score_ann)
print('LSTM: %f'%score_lstm)
# Out:
# ANN: 0.000587
# LSTM: 0.000201

# %%
y_pred_test_ANN2 = model_ann2.predict(X_test2)
y_pred_test_LSTM2 = model_lstm2.predict(X_tst_t2)
y_train_pred_lstm2 = model_lstm2.predict(X_tr_t2)

# %%
col1a = pd.DataFrame(y_test2, columns=['True'])
col2a = pd.DataFrame(y_pred_test_ANN2, columns=['ANN_prediction'])
col3a = pd.DataFrame(y_pred_test_LSTM2, columns=['LSTM_prediction'])
col4a = pd.DataFrame(history.history['loss'], columns=['Loss_ANN'])
col5a = pd.DataFrame(history_model_lstm.history['loss'], columns=['Loss_LSTM'])
results2 = pd.concat([col1a, col2a, col3a, col4a, col5a], axis=1)
results2.to_excel('PredictionResults_ANN-LSTM_NonShift2.xlsx')

# %%
plt.plot(y_test2, label='True')
plt.plot(y_pred_test_ANN2, label='ANN')
plt.title("ANN's_Prediction")
plt.xlabel('Observation')
plt.ylabel('Price_Scaled')
plt.legend()
plt.show()

# %%
plt.plot(y_test2, label='True')
plt.plot(y_pred_test_LSTM2, label='LSTM')
plt.title("LSTM's_Prediction Forecast")
plt.xlabel('Observation')
plt.ylabel("Price_Scaled")
plt.legend()
plt.show()

# %%
plt.plot(y_train2, label='True')
plt.plot(y_train_pred_lstm2, label='LSTM')
plt.title("LSTM's_Prediction on Training")
plt.xlabel('Observation')
plt.ylabel('Price_Scaled')
plt.legend()
plt.show()
